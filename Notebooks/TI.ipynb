# %% [markdown]
# In This notebook we discuss the concept of Temporal Interference

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import functions as fn

# %% [markdown]
# Define simulation parameters

# %%
Sim_period = .1  # seconds
Sim_fs = 100000  # samples per second

Sim_dt = 1/Sim_fs
Sim_t = np.arange(0, Sim_period, Sim_dt)

# %% [markdown]
# Define the signal

# %%
sig1 = fn.gen_sin(init_time=0, freq=200, phase=0.25, time_points=Sim_t)
sig2 = fn.gen_sin(init_time=0, freq=210, phase=0.25, time_points=Sim_t)

# %% [markdown]
# Define the style of the plot

# %%
fig, ax = plt.subplots(figsize=(6, 2), dpi=500)

# remove the 
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# remove the x and y ticks
ax.set_yticks([],[])
ax.set_xticks([],[])

ax.plot(
#     Sim_t, sig1, 'b',
    Sim_t, sig2, 'k' ,
    lineWidth=2
)

save = False
# save the figure

if save:
    name = 'sig_2'
    plt.savefig('D:/TUM/Semester 3 - Holidays/Symposium/Presentation/Figures/TI/'+name+'.jpg')

# %% [markdown]
# ### plot them together

# %%
fig, ax = plt.subplots(figsize=(4, 2), dpi=500)

# remove the 
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# remove the x and y ticks
ax.set_yticks([],[])
ax.set_xticks([],[])

ax.plot(
#     Sim_t, sig1, 'b'
#     , Sim_t, sig2, 'k', 
    Sim_t, sig1 + sig2, 'r'
    , lineWidth=1)

save = False
# save the figure

if save:
    name = 'sig_AM_alone'
    plt.savefig('D:/TUM/Semester 3 - Holidays/Symposium/Presentation/Figures/TI/'+name+'.jpg')

# %% [markdown]
# ### Create the envelope using a sinusoid

# %%
 from scipy.signal import hilbert, chirp

# %%
signal = sig1 + sig2
signal_envelope = np.abs(hilbert(signal))

# %%
fig, ax = plt.subplots(figsize=(4, 2), dpi=500)

# remove the 
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# remove the x and y ticks
ax.set_yticks([],[])
ax.set_xticks([],[])

ax.plot(
    Sim_t, sig1 + sig2, 'r',
    lineWidth=1)

save = False
# save the figure

if save:
    name = 'sig_AM_paper_envelope_alone'
    plt.savefig('D:/TUM/Semester 3 - Holidays/Symposium/Presentation/Figures/TI/'+name+'.jpg')

# %% [markdown]
# ### Save the signal as audio file

# %%
from scipy.io import wavfile

# %%
name = 'sig_AM_paper_envelope_alone'
folder = 'D:/TUM/Semester 3 - Holidays/Symposium/Presentation/Figures/TI/'

path_name = folder + name + '.wav' 
wavfile.write(path_name, Sim_fs, sig1 + sig2)
